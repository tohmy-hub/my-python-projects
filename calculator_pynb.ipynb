# %% [markdown]
# <a href="https://colab.research.google.com/github/tohmy-hub/my-python-projects/blob/main/calculator_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
print("Select operation: add, sub, div, mul")
op = input("Enter operation: ")

if (op == "add"):
    print("Result: " , a + b)
elif (op == "sub"):
  print("Result: " ,a - b)
elif (op == "mul"):
  print("Result: ",a * b)
elif (op == "div"):
  if b == 0:
    print("Error: cannot divide by zero")
  else:
     print("Result:", a / b)
else:
     print("Invalid operation")
# Out:
# Enter the first number: 2098765444
# Enter the second number: 234565434565434
# Select operation: add, sub, div, mul
# Enter operation: mul
# Result:  4.9229782842277604e+23

# %%
import cmath

print("Quadratic Equations YAY!!!!!!!!")

a = float(input("Type a: "))
b = float(input("Type b: "))
c = float(input("Type c: "))

d = b*b -(4*a*c)

x1 = (-b + cmath.sqrt(d)) / (2 * a)
x2 = (-b - cmath.sqrt(d)) / (2 * a)

print("First answer is: ", x1)
print("Second answer is: ", x2)
# Out:
# Quadratic Equations YAY!!!!!!!!
# Type a: 4
# Type b: 9
# Type c: 1098
# First answer is:  (-1.125+16.529802630400642j)
# Second answer is:  (-1.125-16.529802630400642j)
